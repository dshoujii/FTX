# %%
import requests
from bs4 import BeautifulSoup
from openpyxl import Workbook
import time

# %%
url_list =[]

for i in range(652,5008):
    url = 'https://www.whatifsports.com/nba-l/profile_player.asp?pid=' + str(i) + '&view=1'
    url_list.append(url)

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36",
}
cookies = {
    "ASP.NET_SessionId": "0azrrufctd1jogfdx5eibomi"
}

# %%
data = []

i = 651

for url in url_list:
    response = requests.get(url,headers=headers,cookies=cookies)
    i = i + 1
    print('爬到第'+ str(i)+ '个网页')
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        name = soup.select('h4')[0].text
        soup.select_one('#tbl_realstats tr:first-of-type').decompose()
        soup.select_one('#tbl_realstats tr:last-of-type').decompose()
        for row in soup.select('#tbl_realstats tr'):
            row_data = [name]
            for cell in row.find_all('td'):
                row_data.append(cell.text)
            data.append(row_data)
    # time.sleep(0.1)
# Out:
# 爬到第652个网页
# 爬到第653个网页
# 爬到第654个网页
# 爬到第655个网页
# 爬到第656个网页
# 爬到第657个网页
# 爬到第658个网页
# 爬到第659个网页
# 爬到第660个网页
# 爬到第661个网页
# 爬到第662个网页
# 爬到第663个网页
# 爬到第664个网页
# 爬到第665个网页
# 爬到第666个网页
# 爬到第667个网页
# 爬到第668个网页
# 爬到第669个网页
# 爬到第670个网页
# 爬到第671个网页
# 爬到第672个网页
# 爬到第673个网页
# 爬到第674个网页
# 爬到第675个网页
# 爬到第676个网页
# 爬到第677个网页
# 爬到第678个网页
# 爬到第679个网页
# 爬到第680个网页
# 爬到第681个网页
# 爬到第682个网页
# 爬到第683个网页
# 爬到第684个网页
# 爬到第685个网页
# 爬到第686个网页
# 爬到第687个网页
# 爬到第688个网页
# 爬到第689个网页
# 爬到第690个网页
# 爬到第691个网页
# 爬到第692个网页
# 爬到第693个网页
# 爬到第694个网页
# 爬到第695个网页
# 爬到第696个网页
# 爬到第697个网页
# 爬到第698个网页
# 爬到第699个网页
# 爬到第700个网页
# 爬到第701个网页
# 爬到第702个网页
# 爬到第703个网页
# 爬到第704个网页
# 爬到第705个网页
# 爬到第706个网页
# 爬到第707个网页
# 爬到第708个网页
# 爬到第709个网页
# 爬到第710个网页
# 爬到第711个网页
# 爬到第712个网页
# 爬到第713个网页
# 爬到第714个网页
# 爬到第715个网页
# 爬到第716个网页
# 爬到第717个网页
# 爬到第718个网页
# 爬到第719个网页
# 爬到第720个网页
# 爬到第721个网页
# 爬到第722个网页
# 爬到第723个网页
# 爬到第724个网页
# 爬到第725个网页
# 爬到第726个网页
# 爬到第727个网页
# 爬到第728个网页
# 爬到第729个网页
# 爬到第730个网页
# 爬到第731个网页
# 爬到第732个网页
# 爬到第733个网页
# 爬到第734个网页
# ...

# %%
# first_row = ['Name','Team','Pos','GP','Min','Pts','FG%','3Pt%','Ft%','Oreb','Reb','Ast','TO','Stl','Blk','PF','GMSC']
#
# data.insert(0,first_row)

wb = Workbook()

ws = wb.active

for row_data in data:
    ws.append(row_data)

wb.save('GMSC.xlsx')
